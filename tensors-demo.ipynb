# %% [markdown]
# #1 siddhant patel

# %%
'hi'
# Out:
# 'hi'

# %%
import numpy as np

# %%
a=np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
b=np.array([1,2,3,4,5])
print(b)
print(b.ndim)
# Out:
# [1 2 3 4 5]
# 1

# %%
mat = np.array([[1, 3, 4, 5,8], [4,0,4, 4, 4], [6,9, 6, 6, 6]])
#mat.ndim
mat.shape
# Out:
# (3, 5)

# %%
import pandas as pd

# %%
df=pd.read_csv("Instagram data.csv",encoding='latin1')
df
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# ...

# %%
# !kaggle --version
import os
print(os.environ.get("KAGGLE_USERNAME"))
print(os.environ.get("KAGGLE_API_KEY")[:5])
# Out:
# Kaggle API 1.7.4.5
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3764619672.py in <cell line: 0>()
#       2 import os
#       3 print(os.environ.get("KAGGLE_USERNAME"))
# ----> 4 print(os.environ.get("KAGGLE_API_KEY")[:5])
#
# TypeError: 'NoneType' object is not subscriptable
